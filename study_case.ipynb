# %% [markdown]
# # Study case
#
# Study case for the thesis

# %%
import numpy as np
import pandas as pd

from ucimlrepo import fetch_ucirepo

import leader_implementation as lead

# %%
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 

# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets

varinfo = heart_disease.variables

varinfo.loc[varinfo['name'] == 'fbs', 'type'] = 'Binary'
varinfo.loc[varinfo['name'] == 'exang', 'type'] = 'Binary'

varinfo
# Out:
#         name     role         type demographic  \
# 0        age  Feature      Integer         Age
# 1        sex  Feature  Categorical         Sex
# 2         cp  Feature  Categorical        None
# 3   trestbps  Feature      Integer        None
# 4       chol  Feature      Integer        None
# 5        fbs  Feature       Binary        None
# 6    restecg  Feature  Categorical        None
# 7    thalach  Feature      Integer        None
# 8      exang  Feature       Binary        None
# 9    oldpeak  Feature      Integer        None
# 10     slope  Feature  Categorical        None
# 11        ca  Feature      Integer        None
# 12      thal  Feature  Categorical        None
# 13       num   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None  years             no
# 1                                                None   None             no
# 2                                                None   None             no
# 3   resting blood pressure (on admission to the ho...  mm Hg             no
# 4                                   serum cholestoral  mg/dl             no
# 5                     fasting blood sugar > 120 mg/dl   None             no
# 6                                                None   None             no
# 7                         maximum heart rate achieved   None             no
# 8                             exercise induced angina   None             no
# 9   ST depression induced by exercise relative to ...   None             no
# 10                                               None   None             no
# 11  number of major vessels (0-3) colored by flour...   None            yes
# 12                                               None   None            yes
# 13                         diagnosis of heart disease   None             no

# %% [markdown]
# ### s_min election

# %%
leader = lead.LeaderAlgorithms(X, varinfo, similarity_func='gower', seed=42)
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Mean similarity: 0.64
# Quartiles: [0.56  0.64  0.73]

# %%
s_min = 0.6

# %% [markdown]
# ### Leader

# %%
k, leaders, clusters = leader.Leader(s_min=s_min)
# Out:
#                  Leader
#
# =========SUMMARY OF STATISTICS==========
#
# Algorithm executed in 2.70 seconds
#
# 6 clusters have been found:
#
#  Cluster 1     Leader: 0
#                Size: 110
#                Average similarity: 0.6664
# ----------------------------------------
#  Cluster 2     Leader: 1
#                Size: 76
#                Average similarity: 0.7000
# ----------------------------------------
#  Cluster 3     Leader: 4
#                Size: 88
#                Average similarity: 0.7397
# ----------------------------------------
#  Cluster 4     Leader: 14
#                Size: 25
#                Average similarity: 0.7967
# ----------------------------------------
#  Cluster 5     Leader: 91
#                Size: 3
#                Average similarity: 0.8314
# ----------------------------------------
#  Cluster 6     Leader: 152
#                Size: 1
#                Average similarity: 1.0000
# ----------------------------------------

# %%
leader.plot_silhouette()
# Out:
# Cluster 1 has average silhouette width: -0.10
# Cluster 2 has average silhouette width: 0.01
# Cluster 3 has average silhouette width: 0.03
# Cluster 4 has average silhouette width: 0.24
# Cluster 5 has average silhouette width: 0.23
# Cluster 6 has average silhouette width: 0.42
# For the entire dataset, the average silhouette width is: -0.00

# %%
leader.plot_graph()

# %%
leader.plot_clustering_summary()
# Out:
# c:\Users\marti\Desktop\educacio\DADES\TFG\implementation\leader_implementation.py:1262: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(bars, rotation=45, ha='right')

# %%
leader.cluster_boxplots()

# %% [markdown]
# ### Leader2

# %%
k2, leaders2, clusters2 = leader.Leader2(s_min=s_min)
# Out:
#                 Leader2
#
# =========SUMMARY OF STATISTICS==========
#
# Algorithm executed in 2.37 seconds
#
# 6 clusters have been found:
#
#  Cluster 1     Leader: 0
#                Size: 21
#                Average similarity: 0.7442
# ----------------------------------------
#  Cluster 2     Leader: 1
#                Size: 67
#                Average similarity: 0.7580
# ----------------------------------------
#  Cluster 3     Leader: 4
#                Size: 89
#                Average similarity: 0.7759
# ----------------------------------------
#  Cluster 4     Leader: 14
#                Size: 94
#                Average similarity: 0.7647
# ----------------------------------------
#  Cluster 5     Leader: 91
#                Size: 9
#                Average similarity: 0.7699
# ----------------------------------------
#  Cluster 6     Leader: 152
#                Size: 23
#                Average similarity: 0.7485
# ----------------------------------------

# %%
leader.plot_silhouette()
# Out:
# Cluster 1 has average silhouette width: 0.11
# Cluster 2 has average silhouette width: 0.14
# Cluster 3 has average silhouette width: 0.13
# Cluster 4 has average silhouette width: 0.15
# Cluster 5 has average silhouette width: 0.13
# Cluster 6 has average silhouette width: 0.08
# For the entire dataset, the average silhouette width is: 0.13

# %%
leader.plot_graph()

# %%
leader.plot_clustering_summary()
# Out:
# c:\Users\marti\Desktop\educacio\DADES\TFG\implementation\leader_implementation.py:1262: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(bars, rotation=45, ha='right')

# %%
leader.cluster_boxplots()

# %% [markdown]
# ### Leader-Medoid

# %%
k_medoid, leaders_medoid, clusters_medoid = leader.Leader_Medoid(s_min=s_min)
# Out:
#              Leader Medoid
#
# =========SUMMARY OF STATISTICS==========
#
# Algorithm executed in 5.41 seconds
#
# 6 clusters have been found:
#
#  Cluster 1     Leader: 89
#                Size: 52
#                Average similarity: 0.7983
# ----------------------------------------
#  Cluster 2     Leader: 8
#                Size: 131
#                Average similarity: 0.7999
# ----------------------------------------
#  Cluster 3     Leader: 263
#                Size: 104
#                Average similarity: 0.8120
# ----------------------------------------
#  Cluster 4     Leader: 243
#                Size: 7
#                Average similarity: 0.7948
# ----------------------------------------
#  Cluster 5     Leader: 279
#                Size: 7
#                Average similarity: 0.8801
# ----------------------------------------
#  Cluster 6     Leader: 285
#                Size: 2
#                Average similarity: 0.8647
# ----------------------------------------

# %%
leader.plot_silhouette()
# Out:
# Cluster 1 has average silhouette width: 0.03
# Cluster 2 has average silhouette width: 0.11
# Cluster 3 has average silhouette width: 0.07
# Cluster 4 has average silhouette width: 0.06
# Cluster 5 has average silhouette width: 0.20
# Cluster 6 has average silhouette width: 0.26
# For the entire dataset, the average silhouette width is: 0.09

# %%
leader.plot_graph()

# %%
leader.plot_clustering_summary()
# Out:
# c:\Users\marti\Desktop\educacio\DADES\TFG\implementation\leader_implementation.py:1262: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(bars, rotation=45, ha='right')

# %%
leader.cluster_boxplots()

# %% [markdown]
# ### Leader2-Medoid

# %%
k2_medoid, leaders2_medoid, clusters2_medoid = leader.Leader2_Medoid(s_min=s_min)
# Out:
#              Leader2 Medoid
#
# =========SUMMARY OF STATISTICS==========
#
# Algorithm executed in 12.20 seconds
#
# 6 clusters have been found:
#
#  Cluster 1     Leader: 89
#                Size: 43
#                Average similarity: 0.8186
# ----------------------------------------
#  Cluster 2     Leader: 8
#                Size: 120
#                Average similarity: 0.8081
# ----------------------------------------
#  Cluster 3     Leader: 263
#                Size: 98
#                Average similarity: 0.8192
# ----------------------------------------
#  Cluster 4     Leader: 287
#                Size: 8
#                Average similarity: 0.8282
# ----------------------------------------
#  Cluster 5     Leader: 279
#                Size: 31
#                Average similarity: 0.8266
# ----------------------------------------
#  Cluster 6     Leader: 292
#                Size: 3
#                Average similarity: 0.8218
# ----------------------------------------

# %%
leader.plot_silhouette()
# Out:
# Cluster 1 has average silhouette width: 0.07
# Cluster 2 has average silhouette width: 0.09
# Cluster 3 has average silhouette width: 0.05
# Cluster 4 has average silhouette width: 0.12
# Cluster 5 has average silhouette width: 0.11
# Cluster 6 has average silhouette width: 0.21
# For the entire dataset, the average silhouette width is: 0.08

# %%
leader.plot_graph()

# %%
leader.plot_clustering_summary()
# Out:
# c:\Users\marti\Desktop\educacio\DADES\TFG\implementation\leader_implementation.py:1262: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(bars, rotation=45, ha='right')

# %%
leader.cluster_boxplots()

# %% [markdown]
# ### Leader3 Medoid

# %%
k3_medoid, leaders3_medoid, clusters3_medoid = leader.Leader3_Medoid(s_min=s_min)
# Out:
#              Leader3 Medoid
#
# =========SUMMARY OF STATISTICS==========
#
# Algorithm executed in 5.87 seconds
#
# 5 clusters have been found:
#
#  Cluster 1     Leader: 0
#                Size: 9
#                Average similarity: 0.7761
# ----------------------------------------
#  Cluster 2     Leader: 8
#                Size: 106
#                Average similarity: 0.8213
# ----------------------------------------
#  Cluster 3     Leader: 190
#                Size: 134
#                Average similarity: 0.7990
# ----------------------------------------
#  Cluster 4     Leader: 267
#                Size: 19
#                Average similarity: 0.8041
# ----------------------------------------
#  Cluster 5     Leader: 81
#                Size: 35
#                Average similarity: 0.8135
# ----------------------------------------

# %%
leader.plot_silhouette()
# Out:
# Cluster 1 has average silhouette width: 0.10
# Cluster 2 has average silhouette width: 0.11
# Cluster 3 has average silhouette width: 0.12
# Cluster 4 has average silhouette width: 0.10
# Cluster 5 has average silhouette width: 0.17
# For the entire dataset, the average silhouette width is: 0.12

# %%
leader.plot_graph()

# %%
leader.plot_clustering_summary()
# Out:
# c:\Users\marti\Desktop\educacio\DADES\TFG\implementation\leader_implementation.py:1262: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(bars, rotation=45, ha='right')
